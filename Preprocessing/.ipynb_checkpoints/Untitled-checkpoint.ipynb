# %%
import pandas as pd
import os

# %%
path = "../Data/"

# %%
pd.read_csv(path + 'Mutations.csv', sep=';')
# Out:
#         ID                                   Virus name     Accession ID Day  \
# 0        1  hCoV-19/Colombia/ANT-CWOHC-VG-SEC0001A/2021  EPI_ISL_1015353   3
# 1        2  hCoV-19/Colombia/ANT-CWOHC-VG-SEC0002B/2021  EPI_ISL_1015354   5
# 2        3  hCoV-19/Colombia/ANT-CWOHC-VG-SEC0003C/2021  EPI_ISL_1015355   5
# 3        4  hCoV-19/Colombia/ANT-CWOHC-VG-SEC0004D/2021  EPI_ISL_1015356  12
# 4        5  hCoV-19/Colombia/ANT-CWOHC-VG-SEC0005E/2021  EPI_ISL_1015357  12
# ...    ...                                          ...              ...  ..
# 2961  2962          hCoV-19/Colombia/DC-INS-VG-606/2021   EPI_ISL_956303  17
# 2962  2963          hCoV-19/Colombia/DC-INS-VG-456/2021   EPI_ISL_956304  10
# 2963  2964          hCoV-19/Colombia/DC-INS-VG-457/2021   EPI_ISL_956305  10
# 2964  2965        hCoV-19/Colombia/PUT-INS-CVN2151/2020   EPI_ISL_956306   5
# 2965  2966                                          NaN              NaN  20
#
# ...
